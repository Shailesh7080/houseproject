# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.datasets import load_boston
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from sklearn.datasets import load_boston
#
# File ~\anaconda3\Lib\site-packages\sklearn\datasets\__init__.py:157, in __getattr__(name)
#     108 if name == "load_boston":
#     109     msg = textwrap.dedent("""
#     110         `load_boston` has been removed from scikit-learn since version 1.2.
#     111
#    (...)
#     155         <https://www.researchgate.net/publication/4974606_Hedonic_housing_prices_and_the_demand_for_clean_air>
#     156         """)
# --> 157     raise ImportError(msg)
#     158 try:
#     159     return globals()[name]
#
# ImportError:
# `load_boston` has been removed from scikit-learn since version 1.2.
#
# The Boston housing prices dataset has an ethical problem: as
# investigated in [1], the authors of this dataset engineered a
# non-invertible variable "B" assuming that racial self-segregation had a
# positive impact on house prices [2]. Furthermore the goal of the
# research that led to the creation of this dataset was to study the
# impact of air quality but it did not give adequate demonstration of the
# validity of this assumption.
#
# The scikit-learn maintainers therefore strongly discourage the use of
# this dataset unless the purpose of the code is to study and educate
# about ethical issues in data science and machine learning.
#
# In this special case, you can fetch the dataset from the original
# source::
#
#     import pandas as pd
#     import numpy as np
#
#     data_url = "http://lib.stat.cmu.edu/datasets/boston"
#     raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#     data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#     target = raw_df.values[1::2, 2]
#
# Alternative datasets include the California housing dataset and the
# Ames housing dataset. You can load the datasets as follows::
#
#     from sklearn.datasets import fetch_california_housing
#     housing = fetch_california_housing()
#
# for the California housing dataset and::
#
#     from sklearn.datasets import fetch_openml
#     housing = fetch_openml(name="house_prices", as_frame=True)
#
# for the Ames housing dataset.
#
# [1] M Carlisle.
# "Racist data destruction?"
# <https://medium.com/@docintangible/racist-data-destruction-113e3eff54a8>
#
# [2] Harrison Jr, David, and Daniel L. Rubinfeld.
# "Hedonic housing prices and the demand for clean air."
# Journal of environmental economics and management 5.1 (1978): 81-102.
# <https://www.researchgate.net/publication/4974606_Hedonic_housing_prices_and_the_demand_for_clean_air>

# %%
 from sklearn.datasets import fetch_california_housing

# %%
cal=fetch_california_housing()

# %%
cal.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'feature_names', 'DESCR'])

# %%
print(cal.DESCR)
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 20640
#
# :Number of Attributes: 8 numeric, predictive attributes and the target
#
# :Attribute Information:
#     - MedInc        median income in block group
#     - HouseAge      median house age in block group
#     - AveRooms      average number of rooms per household
#     - AveBedrms     average number of bedrooms per household
#     - Population    block group population
#     - AveOccup      average number of household members
#     - Latitude      block group latitude
#     - Longitude     block group longitude
#
# :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# https://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html
#
# The target variable is the median house value for California districts,
# expressed in hundreds of thousands of dollars ($100,000).
#
# This dataset was derived from the 1990 U.S. census, using one row per census
# block group. A block group is the smallest geographical unit for which the U.S.
# Census Bureau publishes sample data (a block group typically has a population
# of 600 to 3,000 people).
#
# A household is a group of people residing within a home. Since the average
# number of rooms and bedrooms in this dataset are provided per household, these
# columns may take surprisingly large values for block groups with few households
# and many empty houses, such as vacation resorts.
#
# It can be downloaded/loaded using the
# :func:`sklearn.datasets.fetch_california_housing` function.
#
# .. topic:: References
#
#     - Pace, R. Kelley and Ronald Barry, Sparse Spatial Autoregressions,
#       Statistics and Probability Letters, 33 (1997) 291-297

# %%
print(cal.data)
# Out:
# [[   8.3252       41.            6.98412698 ...    2.55555556
#     37.88       -122.23      ]
#  [   8.3014       21.            6.23813708 ...    2.10984183
#     37.86       -122.22      ]
#  [   7.2574       52.            8.28813559 ...    2.80225989
#     37.85       -122.24      ]
#  ...
#  [   1.7          17.            5.20554273 ...    2.3256351
#     39.43       -121.22      ]
#  [   1.8672       18.            5.32951289 ...    2.12320917
#     39.43       -121.32      ]
#  [   2.3886       16.            5.25471698 ...    2.61698113
#     39.37       -121.24      ]]

# %%
print(cal.target)
# Out:
# [4.526 3.585 3.521 ... 0.923 0.847 0.894]

# %%
print(cal.feature_names)
# Out:
# ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude']

# %%
df=pd.DataFrame(cal.data,columns=cal.feature_names)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9060\3319477830.py in <module>
# ----> 1 df=pd.DataFrame(cal.data,columns=cal.feature_names)
#
# NameError: name 'cal' is not defined

# %%
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
df['Price']=cal.target

# %%
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  Price
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %%
file_path=r"C:\Users\surya\Downloads\BostonHousing.csv"
df=pd.df=pd.read_csv(file_path)
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       501 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  501.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284341
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.705587
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.884000
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208000
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.625000
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             lstat        medv
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
df.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         5
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %%
plt.figure(figsize=(2,2))
for column in df:
    plt.boxplot(df[column],vert=False)
    plt.title(column)
    plt.show()

# %%
#
#correlation
df.corr()
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219433  0.352734
# zn      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311173 -0.569537
# indus    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.394193  0.644779
# chas    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091468  0.086518
# nox      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302751  0.731470
# rm      -0.219433  0.311173 -0.394193  0.091468 -0.302751  1.000000 -0.240286
# age      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240286  1.000000
# dis     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.203507 -0.747881
# rad      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.210718  0.456022
# tax      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292794  0.506456
# ptratio  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.357612  0.261515
# b       -0.385064  0.175520 -0.356977  0.048788 -0.380051  0.128107 -0.273534
# lstat    0.455621 -0.412995  0.603800 -0.053929  0.590879 -0.615721  0.602339
# medv    -0.388305  0.360445 -0.483725  0.175260 -0.427321  0.696169 -0.376955
#
#               dis       rad       tax   ptratio         b     lstat      medv
# crim    -0.379670  0.625505  0.582764  0.289946 -0.385064  0.455621 -0.388305
# zn       0.664408 -0.311948 -0.314563 -0.391679  0.175520 -0.412995  0.360445
# indus   -0.708027  0.595129  0.720760  0.383248 -0.356977  0.603800 -0.483725
# chas    -0.099176 -0.007368 -0.035587 -0.121515  0.048788 -0.053929  0.175260
# nox     -0.769230  0.611441  0.668023  0.188933 -0.380051  0.590879 -0.427321
# rm       0.203507 -0.210718 -0.292794 -0.357612  0.128107 -0.615721  0.696169
# age     -0.747881  0.456022  0.506456  0.261515 -0.273534  0.602339 -0.376955
# dis      1.000000 -0.494588 -0.534432 -0.232471  0.291512 -0.496996  0.249929
# rad     -0.494588  1.000000  0.910228  0.464741 -0.444413  0.488676 -0.381626
# tax     -0.534432  0.910228  1.000000  0.460853 -0.441808  0.543993 -0.468536
# ptratio -0.232471  0.464741  0.460853  1.000000 -0.177383  0.374044 -0.507787
# b        0.291512 -0.444413 -0.441808 -0.177383  1.000000 -0.366087  0.333461
# lstat   -0.496996  0.488676  0.543993  0.374044 -0.366087  1.000000 -0.737663
# medv     0.249929 -0.381626 -0.468536 -0.507787  0.333461 -0.737663  1.000000

# %%
import seaborn as sns
sns.pairplot(df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9060\789134733.py in <module>
# ----> 1 import seaborn as sns
#       2 sns.pairplot(df)
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
plt.scatter(df['crim'],df['medv'])
plt.xlabel('crimrate')
plt.ylabel('medv')
# Out:
# Text(0, 0.5, 'medv')

# %%
plt.scatter(df['rm'],df['medv'])
plt.xlabel('ave room no')
plt.ylabel('medv')
# Out:
# Text(0, 0.5, 'medv')

# %%
sns.regplot(x='rm',y='medv',data=df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9060\783327134.py in <module>
# ----> 1 sns.regplot(x='rm',y='medv',data=df)
#
# NameError: name 'sns' is not defined

# %%
sns.regplot(x='crim',y='medv',data=df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9060\922907413.py in <module>
# ----> 1 sns.regplot(x='crim',y='medv',data=df)
#
# NameError: name 'sns' is not defined

# %%
sns.regplot(x='chas',y='medv',data=df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9060\1797835236.py in <module>
# ----> 1 sns.regplot(x='chas',y='medv',data=df)
#
# NameError: name 'sns' is not defined

# %%
sns.regplot(x='ptratio',y='medv',data=df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9060\1930251667.py in <module>
# ----> 1 sns.regplot(x='ptratio',y='medv',data=df)
#
# NameError: name 'sns' is not defined

# %%
# independant and dependant
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
x.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat
# 0  396.90   4.98
# 1  396.90   9.14
# 2  392.83   4.03
# 3  394.63   2.94
# 4  396.90   5.33

# %%
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: medv, Length: 506, dtype: float64

# %%
# train test slpit
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
X_train
# Out:
#          crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 5     0.02985   0.0   2.18     0  0.458  6.430  58.7  6.0622    3  222
# 116   0.13158   0.0  10.01     0  0.547  6.176  72.5  2.7301    6  432
# 45    0.17142   0.0   6.91     0  0.448  5.682  33.8  5.1004    3  233
# 16    1.05393   0.0   8.14     0  0.538  5.935  29.3  4.4986    4  307
# 468  15.57570   0.0  18.10     0  0.580  5.926  71.0  2.9084   24  666
# ..        ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 106   0.17120   0.0   8.56     0  0.520  5.836  91.9  2.2110    5  384
# 270   0.29916  20.0   6.96     0  0.464  5.856  42.1  4.4290    3  223
# 348   0.01501  80.0   2.01     0  0.435  6.635  29.7  8.3440    4  280
# 435  11.16040   0.0  18.10     0  0.740  6.629  94.6  2.1247   24  666
# 102   0.22876   0.0   8.56     0  0.520  6.405  85.4  2.7147    5  384
#
#      ptratio       b  lstat
# 5       18.7  394.12   5.21
# 116     17.8  393.30  12.04
# 45      17.9  396.90  10.21
# 16      21.0  386.85   6.58
# 468     20.2  368.74  18.13
# ..       ...     ...    ...
# 106     20.9  395.67  18.66
# 270     18.6  388.65  13.00
# 348     17.0  390.94   5.99
# 435     20.2  109.85  23.27
# 102     20.9   70.80  10.63
#
# [354 rows x 13 columns]

# %%
X_test
# Out:
#         crim    zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 173  0.09178   0.0   4.05     0  0.510  6.416   84.1  2.6463    5  296
# 274  0.05644  40.0   6.41     1  0.447  6.758   32.9  4.0776    4  254
# 491  0.10574   0.0  27.74     0  0.609  5.983   98.8  1.8681    4  711
# 72   0.09164   0.0  10.81     0  0.413  6.065    7.8  5.2873    4  305
# 452  5.09017   0.0  18.10     0  0.713  6.297   91.8  2.3682   24  666
# ..       ...   ...    ...   ...    ...    ...    ...     ...  ...  ...
# 441  9.72418   0.0  18.10     0  0.740  6.406   97.2  2.0651   24  666
# 23   0.98843   0.0   8.14     0  0.538  5.813  100.0  4.0952    4  307
# 225  0.52693   0.0   6.20     0  0.504  8.725   83.0  2.8944    8  307
# 433  5.58107   0.0  18.10     0  0.713  6.436   87.9  2.3158   24  666
# 447  9.92485   0.0  18.10     0  0.740  6.251   96.6  2.1980   24  666
#
#      ptratio       b  lstat
# 173     16.6  395.50   9.04
# 274     17.6  396.90   3.53
# 491     20.1  390.11  18.07
# 72      19.2  390.91   5.52
# 452     20.2  385.09  17.27
# ..       ...     ...    ...
# 441     20.2  385.96  19.52
# 23      21.0  394.54  19.88
# 225     17.4  382.00   4.63
# 433     20.2  100.19  16.22
# 447     20.2  388.52  16.44
#
# [152 rows x 13 columns]

# %%
#standerize the dataset
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)

# %%
X_test=scaler.transform(X_test)

# %%
import pickle
pickle.dump(scaler,open('scaling.pkl','wb'))

# %%
X_train
# Out:
# array([[-0.41425879, -0.50512499, -1.29214218, ...,  0.18727079,
#          0.39651419, -1.01531611],
#        [-0.40200818, -0.50512499, -0.16208345, ..., -0.21208981,
#          0.3870674 , -0.05366252],
#        [-0.39721053, -0.50512499, -0.60948856, ..., -0.16771641,
#          0.42854113, -0.31132373],
#        ...,
#        [-0.41604586,  3.03838247, -1.3166773 , ..., -0.56707702,
#          0.35987906, -0.90549329],
#        [ 0.92611293, -0.50512499,  1.00549958, ...,  0.8528718 ,
#         -2.87841346,  1.52750437],
#        [-0.39030549, -0.50512499, -0.37135358, ...,  1.16348561,
#         -3.32828832, -0.25218837]])

# %%
X_test
# Out:
# array([[-0.406801  , -0.50512499, -1.02225586, ..., -0.74457062,
#          0.41241246, -0.47605794],
#        [-0.41105674,  1.26662874, -0.68165068, ..., -0.30083661,
#          0.42854113, -1.25185755],
#        [-0.4051199 , -0.50512499,  2.39678516, ...,  0.8084984 ,
#          0.35031705,  0.79535229],
#        ...,
#        [-0.35439903, -0.50512499, -0.71195877, ..., -0.38958342,
#          0.25688594, -1.09697922],
#        [ 0.25423453, -0.50512499,  1.00549958, ...,  0.8528718 ,
#         -2.98970133,  0.53487511],
#        [ 0.77732457, -0.50512499,  1.00549958, ...,  0.8528718 ,
#          0.33199949,  0.56585078]])

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(strategy='mean')
X_train = imputer.fit_transform(X_train)
X_test = imputer.transform(X_test)

# %% [markdown]
# # model training

# %%
from sklearn.linear_model import LinearRegression

# %%
regression=LinearRegression()

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(regression.coef_)
# Out:
# [-1.10805091  0.81364034  0.35247183  0.81572385 -1.79461695  2.91610643
#  -0.29531672 -2.9319251   2.10021387 -1.44876527 -2.05914412  1.02252929
#  -3.893139  ]

# %%
print(regression.intercept_)
# Out:
# 23.01581920903955

# %%
## on which parameter the model has been trained
regression.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
# prediction with test data
reg_pred=regression.predict(X_test)

# %%
reg_pred
# Out:
# array([28.62996997, 36.49040307, 15.40800898, 25.39495543, 18.8533242 ,
#        23.13545997, 17.38183062, 14.05580743, 23.03873962, 20.58223904,
#        24.82781558, 18.54315084, -6.85349725, 21.79283746, 19.22068502,
#        26.17845662, 20.28029612,  5.62278131, 40.4356837 , 17.57646896,
#        27.43032997, 30.1612018 , 10.9220398 , 23.99187148, 18.08092795,
#        15.94496391, 23.12206491, 14.55581408, 22.33144131, 19.31373795,
#        22.15617702, 25.1777531 , 25.29227946, 18.53644096, 16.61958332,
#        17.52425388, 30.92868935, 20.18142988, 23.89951088, 24.85618356,
#        13.92540907, 31.80140749, 42.55692489, 17.62217994, 26.99383152,
#        17.19672569, 13.78994878, 26.0877311 , 20.314733  , 30.07733616,
#        21.32649865, 34.1476437 , 15.58018832, 26.08021648, 39.2991466 ,
#        22.9964645 , 18.95771455, 33.04814948, 24.83006973, 12.92643125,
#        20.91823644, 30.80644948, 31.61718688, 16.28696629, 21.09052796,
#        16.57956173, 20.35587441, 26.14508357, 31.06388703, 11.99457837,
#        20.41537001, 27.55376884, 10.94374606, 16.84642429, 23.91834623,
#         5.27709724, 21.40924172, 41.32639276, 18.20750188,  9.48357694,
#        21.19627637, 12.94465184, 21.67494204,  9.39377365, 23.05025787,
#        31.94684343, 19.16107289, 25.58303609, 29.35049533, 20.11523538,
#        25.55966361,  5.43519427, 20.22223591, 15.19431493, 14.08604778,
#        20.90212512, 24.82309041, -0.46788606, 13.70405218, 15.68151555,
#        22.04984941, 24.63155306, 10.74347208, 19.67604648, 23.64319289,
#        12.07496963, 18.46603689, 25.51171226, 20.92509458, 24.71462057,
#         7.58693324, 18.99240403, 21.93433862, 27.19873846, 32.16145697,
#        15.28408103, 34.34398274, 12.95375078, 21.00377475, 28.57707161,
#        15.87958816, 24.8472562 ,  3.38489456, 23.89652842, 25.80936654,
#        23.10014077, 25.35104165, 33.32223312, 20.6298611 , 38.45408171,
#        13.97069618, 25.20227423, 17.79469521, 20.6186051 ,  9.81819163,
#        21.07795593, 22.32194143, 32.34698894, 31.48860628, 15.45078555,
#        16.84528511, 29.01289063, 24.9730865 , 16.73438874,  6.12668895,
#        26.6608353 , 23.36141402, 17.39758578, 13.36805083, 39.93138983,
#        16.68277189, 18.28603862])

# %%
# plot a scatter plot for prediction
plt.scatter(y_test,reg_pred)

# %%
residual=y_test-reg_pred
residual
# Out:
# 173    -5.029970
# 274    -4.090403
# 491    -1.808009
# 72     -2.594955
# 452    -2.753324
#          ...
# 441    -0.297586
# 23      1.131949
# 225    10.068610
# 433    -2.382772
# 447    -5.686039
# Name: medv, Length: 152, dtype: float64

# %%
# prediction with residual
sns.displot(residual,kind='kde')

# %%
## SCATTER plot with respect to prediction and resiudual
plt.scatter(reg_pred,residual)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

print(mean_absolute_error(y_test,reg_pred))
print(mean_squared_error(y_test,reg_pred))
print(np.sqrt(mean_squared_error(y_test,reg_pred)))
# Out:
# 3.1728221898473468
# 21.587110780162902
# 4.64619314925272

# %%
# R square and adjusted r square
from sklearn.metrics import r2_score
score=r2_score(y_test,reg_pred)
print(score)
# Out:
# 0.7102910486318312

# %%
1-(1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# 0.6829996256768588

# %% [markdown]
# # pickling the model file for deployment

# %%
import pickle

# %%
pickle.dump(regression,open('regmodel.pkl','wb'))

# %%
pickle_model=pickle.load(open('regmodel.pkl','rb'))

# %%
pickle_model.predict(X_test)
# Out:
# array([28.62996997, 36.49040307, 15.40800898, 25.39495543, 18.8533242 ,
#        23.13545997, 17.38183062, 14.05580743, 23.03873962, 20.58223904,
#        24.82781558, 18.54315084, -6.85349725, 21.79283746, 19.22068502,
#        26.17845662, 20.28029612,  5.62278131, 40.4356837 , 17.57646896,
#        27.43032997, 30.1612018 , 10.9220398 , 23.99187148, 18.08092795,
#        15.94496391, 23.12206491, 14.55581408, 22.33144131, 19.31373795,
#        22.15617702, 25.1777531 , 25.29227946, 18.53644096, 16.61958332,
#        17.52425388, 30.92868935, 20.18142988, 23.89951088, 24.85618356,
#        13.92540907, 31.80140749, 42.55692489, 17.62217994, 26.99383152,
#        17.19672569, 13.78994878, 26.0877311 , 20.314733  , 30.07733616,
#        21.32649865, 34.1476437 , 15.58018832, 26.08021648, 39.2991466 ,
#        22.9964645 , 18.95771455, 33.04814948, 24.83006973, 12.92643125,
#        20.91823644, 30.80644948, 31.61718688, 16.28696629, 21.09052796,
#        16.57956173, 20.35587441, 26.14508357, 31.06388703, 11.99457837,
#        20.41537001, 27.55376884, 10.94374606, 16.84642429, 23.91834623,
#         5.27709724, 21.40924172, 41.32639276, 18.20750188,  9.48357694,
#        21.19627637, 12.94465184, 21.67494204,  9.39377365, 23.05025787,
#        31.94684343, 19.16107289, 25.58303609, 29.35049533, 20.11523538,
#        25.55966361,  5.43519427, 20.22223591, 15.19431493, 14.08604778,
#        20.90212512, 24.82309041, -0.46788606, 13.70405218, 15.68151555,
#        22.04984941, 24.63155306, 10.74347208, 19.67604648, 23.64319289,
#        12.07496963, 18.46603689, 25.51171226, 20.92509458, 24.71462057,
#         7.58693324, 18.99240403, 21.93433862, 27.19873846, 32.16145697,
#        15.28408103, 34.34398274, 12.95375078, 21.00377475, 28.57707161,
#        15.87958816, 24.8472562 ,  3.38489456, 23.89652842, 25.80936654,
#        23.10014077, 25.35104165, 33.32223312, 20.6298611 , 38.45408171,
#        13.97069618, 25.20227423, 17.79469521, 20.6186051 ,  9.81819163,
#        21.07795593, 22.32194143, 32.34698894, 31.48860628, 15.45078555,
#        16.84528511, 29.01289063, 24.9730865 , 16.73438874,  6.12668895,
#        26.6608353 , 23.36141402, 17.39758578, 13.36805083, 39.93138983,
#        16.68277189, 18.28603862])

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\surya'
